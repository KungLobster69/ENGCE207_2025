# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np



# สร้างข้อมูลจำลอง
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.7, random_state=0)


# กำหนดสีสำหรับแต่ละกลุ่ม
colors = ['skyblue', 'pink', 'limegreen', 'yellow']


# แสดงผลข้อมูลด้วย scatter plot กำหนดสีเอง
for i in range(4):
    plt.scatter(X[y == i, 0], X[y == i, 1], color=colors[i], label=f'กลุ่มที่ {i+1}', s=60)

plt.title("จำลองข้อมูลด้วย make_blobs (กำหนดสีเอง)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()
 







#2.2
from sklearn.cluster import KMeans
import numpy as np
#ตัวช่วยในการคํานวณ
# คำนวณค่า inertia สำหรับจำนวนกลุ่มตั้งแต่ 1 ถึง 10
inertia = []
#สร้าง list ว่างๆ สำหรับเก็บค่า Inertia ซึ่งคือผลรวมของระยะทางกำลังสองระหว่างแต่ละจุดข้อมูลกับ centroid ของกลุ่มที่มันถูกจัดอยู่
K_range = range(1, 11)
#สร้างช่วงของจำนวนกลุ่ม k ที่จะลอง คือ ตั้งแต่ 1 ถึง 10
for k in K_range:
    #วนซ้ำค่าของตัวแปร k จาก K_range
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_synth)
    inertia.append(kmeans.inertia_)

# พล๊อตกราฟ Elbow
plt.plot(K_range, inertia, marker='o')
plt.title("Elbow Method")
plt.xlabel("จำนวนกลุ่ม (k)")
plt.ylabel("ค่า Inertia")
plt.xticks(K_range)
plt.grid(True)
plt.show()












#2.3เปรียบเทียบ
# สร้างโมเดล KMeans ด้วยจำนวนกลุ่มที่ถูกต้อง
kmeans_final = KMeans(n_clusters=4, random_state=42)
y_pred = kmeans_final.fit_predict(X_synth)

# เปรียบเทียบผลลัพธ์การจัดกลุ่ม
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# กลุ่มที่แท้จริง
ax1.scatter(X_synth[:, 0], X_synth[:, 1], c=y_true, cmap='viridis', s=30)
ax1.set_title("กลุ่มที่แท้จริง (y_true)")

# กลุ่มที่ได้จาก K-Means
ax2.scatter(X_synth[:, 0], X_synth[:, 1], c=y_pred, cmap='viridis', s=30)
ax2.set_title("ผลลัพธ์จาก K-Means")

plt.show()
# Out:
# c:\Users\Lenovo\Desktop\ENGEE207_68143206005-8\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3635 (\N{THAI CHARACTER SARA AM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Lenovo\Desktop\ENGEE207_68143206005-8\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Lenovo\Desktop\ENGEE207_68143206005-8\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Lenovo\Desktop\ENGEE207_68143206005-8\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3641 (\N{THAI CHARACTER SARA UU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
