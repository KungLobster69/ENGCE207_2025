# %%
import pandas as pd
import numpy as np

df = pd.read_csv('vgsales.csv')

print("--- ส่วนที่ 4: การจัดการข้อมูลอื่นๆ และการสร้างคอลัมน์ใหม่")

# 4.1 การเรียงลำดับข้อมูล
print("\n4.1 เรียงลำดับข้อมูลตาม Global_Sale', (มากไปน้อย):")
df_sorted = df.sort_values(by='Global_Sales', ascending=False)
print(df_sorted.head())

# 4.2 การสร้างคอลัมน์ใหม่ (Feature Engineering)
print("\4.2.1 สร้างคอลัมน์ 'Sales_Outside_JP':")
df['Sales_Outside_JP'] = df['NA_Sales'] + df['EU_Sales'] + df['Other_Sales']
print(df[['Name', 'NA_Sales', 'EU_Sales', 'Other_Sales', 'Sales_Outside_JP']].head())

print("\n4.2.2 สร้างคอลัมน์ 'Release_decade':")
# First, convert 'Year' colum to integer type as it was float
df['Year'] = df['Year'].astype('Int64')  

# Define the Funtion to find the decade
def find_decade(year):
    if 1980 <= year < 1990:
        return '1980s'
    elif 1990 <= year < 2000:
        return '1990s'
    elif 2000 <= year < 2010:
        return '2000s'
    else:
        return '2010s_and_later'
    
# Apply the Functions to the 'Year'    
df['Release_Decade'] = df['Year'].apply(find_decade)
print(df[['Name', 'Year', 'Release_Decade']])

print("\n--- สิ้นสุดส่วนที่ 4 ---\n" + "="*50 + "\n")
# Out:
# --- ส่วนที่ 4: การจัดการข้อมูลอื่นๆ และการสร้างคอลัมน์ใหม่
#
# 4.1 เรียงลำดับข้อมูลตาม Global_Sale', (มากไปน้อย):
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# .2.1 สร้างคอลัมน์ 'Sales_Outside_JP':
#                        Name  NA_Sales  EU_Sales  Other_Sales  Sales_Outside_JP
# 0                Wii Sports     41.49     29.02         8.46             78.97
# 1         Super Mario Bros.     29.08      3.58         0.77             33.43
# 2            Mario Kart Wii     15.85     12.88         3.31             32.04
# 3         Wii Sports Resort     15.75     11.01         2.96             29.72
# 4  Pokemon Red/Pokemon Blue     11.27      8.89         1.00             21.16
#
# 4.2.2 สร้างคอลัมน์ 'Release_decade':
#                                                    Name  Year   Release_Decade
# 0                                            Wii Sports  2006            2000s
# 1                                     Super Mario Bros.  1985            1980s
# 2                                        Mario Kart Wii  2008            2000s
# 3                                     Wii Sports Resort  2009            2000s
# 4                              Pokemon Red/Pokemon Blue  1996            1990s
# ...                                                 ...   ...              ...
# 16593                Woody Woodpecker in Crazy Castle 5  2002            2000s
# 16594                     Men in Black II: Alien Escape  2003            2000s
# 16595  SCORE International Baja 1000: The Official Game  2008            2000s
# 16596                                        Know How 2  2010  2010s_and_later
# 16597                                  Spirits & Spells  2003            2000s
#
# [16598 rows x 3 columns]
#
# --- สิ้นสุดส่วนที่ 4 ---
# ==================================================
