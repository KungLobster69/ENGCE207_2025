# %%
# !pip install scikit-learn

# %%
pip install scikit-learn

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# สร้างข้อมูลจำลอง
X, y_true = make_blobs(n_samples=300, centers=4, cluster_std=0.7, random_state=42)

# แสดงผลข้อมูลด้วย Scatter plot
plt.figure(figsize=(8 , 6))
plt.scatter(X[:, 0], X[:, 1], c='blue', s=50, alpha=0.6, edgecolors='w')
plt.title("Scatter plot ของข้อมูลที่สร้างขึ้น")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.show()
# Out:
# C:\Users\KOSIN\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KOSIN\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KOSIN\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KOSIN\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# 1 & 2. สร้างข้อมูลตัวอย่าง
X_synth, y_true = make_blobs(n_samples=300, centers=4, cluster_std=0.70, random_state=0)

# 3. พล็อตข้อมูล
plt.figure(figsize=(10, 6))
plt.scatter(X_synth[:, 0], X_synth[:, 1], s=50)
plt.title('Synthetic Data Distribution')
plt.grid(True)
plt.show()
